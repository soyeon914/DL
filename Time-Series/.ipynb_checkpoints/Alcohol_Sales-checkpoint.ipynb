# %% [markdown]
# ## <u><b>[Udemy] 시계열 데이터 분석 with 파이썬 - 83

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/Alcohol_Sales.csv', index_col='DATE', parse_dates=True)
df.index.freq = 'MS'

# %%
df.head()
# Out:
#             S4248SM144SCEN
# DATE
# 1992-01-01            4302
# 1992-02-01            4323
# 1992-03-01            4199
# 1992-04-01            4397
# 1992-05-01            4159

# %%
df.columns = ['Sales']

# %%
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
# !python -m pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (0.13.5)
# Requirement already satisfied: patsy>=0.5.2 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pandas>=0.25 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: scipy>=1.3 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: packaging>=21.3 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels) (23.0)
# Requirement already satisfied: numpy>=1.17 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['Sales'])

# %%
results.plot();

# %%
results.seasonal.plot(figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
results.seasonal
# Out:
# DATE
# 1992-01-01    33.686718
# 1992-02-01    10.996440
# 1992-03-01    -4.603560
# 1992-04-01   -43.289671
# 1992-05-01    -6.609116
#                 ...
# 2022-07-01    39.795051
# 2022-08-01    28.092273
# 2022-09-01    22.756162
# 2022-10-01    28.981162
# 2022-11-01     6.370051
# Freq: MS, Name: seasonal, Length: 371, dtype: float64

# %%
len(df)
# Out:
# 371

# %%
# 미래 1년 예측
371-12
# Out:
# 359

# %%
train = df.iloc[:359]
test = df.iloc[359:]

# %%
test
# Out:
#             Sales
# DATE
# 2021-12-01  14465
# 2022-01-01  16404
# 2022-02-01  16319
# 2022-03-01  16085
# 2022-04-01  16133
# 2022-05-01  16023
# 2022-06-01  15459
# 2022-07-01  15889
# 2022-08-01  15801
# 2022-09-01  16048
# 2022-10-01  15794
# 2022-11-01  15860

# %%
len(test) # 마지막 년도만 포함됨
# Out:
# 12

# %%
# 정규화 -> 범위가 뒤죽박죽인 데이터를 0~1사이로 정규화

ser = np.array([23, 56, 2, 13, 14]) # original
# 정규화 적용
ser.max() # fit
ser / ser.max() # transform
# Out:
# array([0.41071429, 1.        , 0.03571429, 0.23214286, 0.25      ])

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/inslab/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from scikit-learn) (1.2.0)

# %%
from sklearn.preprocessing import MinMaxScaler # 정규화를 위한 라이브러리

scaler = MinMaxScaler()
scaler.fit(train) # finds the max value in train data
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# #### Generator 알기

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
scaled_train[:5]
# Out:
# array([[0.01749295],
#        [0.01923396],
#        [0.00895374],
#        [0.02536893],
#        [0.00563754]])

# %%
n_input = 3
n_features = 1

generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
len(scaled_train)
# Out:
# 359

# %%
len(generator) # sclaed_train - n_input
# Out:
# 356

# %%
# 위에 설정한 것과 동일한 것을 확인할 수 있음.
# 이를 통해 generator 객체는 원하는 입력 개수대로 데이터를 가져오고 바로 다음 시점을 반환할 수 있음을 알 수 있음.
# 이는 순환 신경망과 연관 있음! 다음 포인트를 정할 수 있기 때문 ~
# 위에 설정한 batch_size는 아래의 데이터를 몇 개의 batch로 할 건지에 대한 것임.
# 계절성이 뚜렷한 데이터셋이라면 순한 신경망이 계절성을 찾을 수 있도록 적어도 input을 12개의 데이터 포인트를 입력할 것

X, y = generator[0]

print(X,"\n") 
print(X.shape,"\n")
print(y)
# Out:
# [[[0.01749295]
#   [0.01923396]
#   [0.00895374]]]
#
# (1, 3, 1)
#
# [[0.02536893]]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

n_input = 12
n_features = 1

train_generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

model = Sequential()

model.add(LSTM(150, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(64))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# Metal device set to: Apple M1
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-01-31 18:20:38.535219: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-31 18:20:38.535387: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150)               91200
#
#  dense (Dense)               (None, 64)                9664
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 100,929
# Trainable params: 100,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(train_generator, epochs=25)
# Out:
# Epoch 1/25
# /var/folders/40/c3b3k6gx3fgb1p9w_gczw1lc0000gn/T/ipykernel_56332/4223744015.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator, epochs=25)
# 2023-01-31 18:20:39.385911: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-01-31 18:20:39.693354: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 347/347 [==============================] - 48s 132ms/step - loss: 0.0027
# Epoch 2/25
# 347/347 [==============================] - 47s 134ms/step - loss: 0.0023
# Epoch 3/25
# 347/347 [==============================] - 46s 134ms/step - loss: 9.3409e-04
# Epoch 4/25
# 347/347 [==============================] - 46s 134ms/step - loss: 0.0010
# Epoch 5/25
# 347/347 [==============================] - 48s 137ms/step - loss: 0.0011
# Epoch 6/25
# 347/347 [==============================] - 47s 134ms/step - loss: 0.0011
# Epoch 7/25
# 347/347 [==============================] - 46s 133ms/step - loss: 9.9381e-04
# Epoch 8/25
# 347/347 [==============================] - 50s 145ms/step - loss: 0.0011
# Epoch 9/25
# 347/347 [==============================] - 52s 149ms/step - loss: 7.1422e-04
# Epoch 10/25
# 347/347 [==============================] - 49s 143ms/step - loss: 0.0011
# Epoch 11/25
# 347/347 [==============================] - 48s 139ms/step - loss: 6.6311e-04
# Epoch 12/25
# 347/347 [==============================] - 49s 142ms/step - loss: 7.4051e-04
# Epoch 13/25
# 347/347 [==============================] - 47s 136ms/step - loss: 0.0012
# Epoch 14/25
# 347/347 [==============================] - 47s 135ms/step - loss: 9.2852e-04
# Epoch 15/25
# 347/347 [==============================] - 46s 132ms/step - loss: 0.0010
# Epoch 16/25
# 347/347 [==============================] - 47s 137ms/step - loss: 7.8652e-04
# Epoch 17/25
# 347/347 [==============================] - 46s 132ms/step - loss: 8.5563e-04
# Epoch 18/25
# 347/347 [==============================] - 47s 136ms/step - loss: 8.4408e-04
# Epoch 19/25
# 347/347 [==============================] - 45s 130ms/step - loss: 8.3814e-04
# Epoch 20/25
# 347/347 [==============================] - 45s 130ms/step - loss: 9.5411e-04
# Epoch 21/25
# 347/347 [==============================] - 45s 129ms/step - loss: 7.9116e-04
# Epoch 22/25
# 347/347 [==============================] - 45s 128ms/step - loss: 8.1264e-04
# Epoch 23/25
# 347/347 [==============================] - 45s 130ms/step - loss: 7.3504e-04
# Epoch 24/25
# 347/347 [==============================] - 45s 129ms/step - loss: 8.6452e-04
# Epoch 25/25
# 347/347 [==============================] - 45s 129ms/step - loss: 6.7214e-04

# %%
model.history.history.keys()
# Out:
# dict_keys([])

# %%
myloss = model.history.history['loss']
plt.plot(range(len(myloss)), myloss)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 myloss = model.history.history['loss']
#       2 plt.plot(range(len(myloss)), myloss)
#
# KeyError: 'loss'

# %%
# 12 history steps ---> step 13
# last 12 point train ---> pt 1 of test data

# %%
first_eval_batch = scaled_train[-12:]
first_eval_batch
# Out:
# array([[0.74166805],
#        [0.95249544],
#        [0.91601724],
#        [0.92447355],
#        [0.96335599],
#        [0.94727243],
#        [0.946775  ],
#        [0.97496269],
#        [0.96716962],
#        [0.95208092],
#        [0.97894213],
#        [1.        ]])

# %%
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# array([[1.0341775]], dtype=float32)

# %%
scaled_test
# Out:
# array([[0.86005638],
#        [1.02080915],
#        [1.01376223],
#        [0.99436246],
#        [0.9983419 ],
#        [0.98922235],
#        [0.94246394],
#        [0.97811308],
#        [0.97081744],
#        [0.99129498],
#        [0.97023711],
#        [0.97570884]])

# %% [markdown]
# #### FORECAST USING RNN MODEL

# %%
# holding my predictions
test_predictions = []

# last n_input points from the training set
first_eval_batch = scaled_train[-n_input:]
# reshape this to the format RNN wants (same format as TimeseriesGenerator)
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# how far into the future will I forecast?
# len(test) --> 24
for i in range(len(test)):
    
    # One timestep ahead of historical 12 points
    current_pred = model.predict(current_batch)[0]
    
    # store that prediction
    test_predictions.append(current_pred)
    
    # UPDATE current batch to include prediction
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis=1)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
test_predictions
# Out:
# [array([1.0341775], dtype=float32),
#  array([1.0583072], dtype=float32),
#  array([1.0824656], dtype=float32),
#  array([1.1074133], dtype=float32),
#  array([1.1331117], dtype=float32),
#  array([1.1590396], dtype=float32),
#  array([1.1854658], dtype=float32),
#  array([1.2125459], dtype=float32),
#  array([1.240143], dtype=float32),
#  array([1.2683358], dtype=float32),
#  array([1.2973459], dtype=float32),
#  array([1.3270276], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[16565.24950838],
#        [16856.30109501],
#        [17147.70065403],
#        [17448.61912727],
#        [17758.59351015],
#        [18071.33585525],
#        [18390.08863258],
#        [18716.72830486],
#        [19049.60416007],
#        [19389.66665173],
#        [19739.58596468],
#        [20097.60642004]])

# %%
test['Predictions'] = true_predictions
# Out:
# /var/folders/40/c3b3k6gx3fgb1p9w_gczw1lc0000gn/T/ipykernel_56332/4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test
# Out:
#             Sales   Predictions
# DATE
# 2021-12-01  14465  16565.249508
# 2022-01-01  16404  16856.301095
# 2022-02-01  16319  17147.700654
# 2022-03-01  16085  17448.619127
# 2022-04-01  16133  17758.593510
# 2022-05-01  16023  18071.335855
# 2022-06-01  15459  18390.088633
# 2022-07-01  15889  18716.728305
# 2022-08-01  15801  19049.604160
# 2022-09-01  16048  19389.666652
# 2022-10-01  15794  19739.585965
# 2022-11-01  15860  20097.606420

# %%
test.plot(figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
model.save('./Model/mycoolmodel.h5')

# %%
pwd
# Out:
# '/Users/inslab/SOYEON/Time-Series'

# %%
from keras.models import load_model

new_model = load_model('./Model/mycoolmodel.h5')

new_model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150)               91200
#
#  dense (Dense)               (None, 64)                9664
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 100,929
# Trainable params: 100,929
# Non-trainable params: 0
# _________________________________________________________________
