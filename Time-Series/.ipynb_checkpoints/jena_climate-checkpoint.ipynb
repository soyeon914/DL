# %%
import tensorflow as tf

tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
fname = os.path.join("./Data/jena_climate_2009_2016.csv")

with open(fname) as f:
    data = f.read()

lines = data.split("\n")
header = lines[0].split(",")
lines = lines[1:]
print(header)
print(len(lines))
# Out:
# ['"Date Time"', '"p (mbar)"', '"T (degC)"', '"Tpot (K)"', '"Tdew (degC)"', '"rh (%)"', '"VPmax (mbar)"', '"VPact (mbar)"', '"VPdef (mbar)"', '"sh (g/kg)"', '"H2OC (mmol/mol)"', '"rho (g/m**3)"', '"wv (m/s)"', '"max. wv (m/s)"', '"wd (deg)"']
# 420451

# %% [markdown]
# ### 데이터 파싱

# %%
import numpy as np
temperature = np.zeros((len(lines),))
raw_data = np.zeros((len(lines), len(header) - 1))
for i, line in enumerate(lines):
    values = [float(x) for x in line.split(",")[1:]]
    temperature[i] = values[1]
    raw_data[i, :] = values[:]

# %%
from matplotlib import pyplot as plt
plt.plot(range(len(temperature)), temperature)
plt.show()

# %%
plt.plot(range(1440), temperature[:1440])
plt.show()

# %%
num_train_samples = int(0.5 * len(raw_data))
num_val_samples = int(0.25 * len(raw_data))
num_test_samples = len(raw_data) - num_train_samples - num_val_samples
print("num_train_samples:", num_train_samples)
print("num_val_samples:", num_val_samples)
print("num_test_samples:", num_test_samples)
# Out:
# num_train_samples: 210225
# num_val_samples: 105112
# num_test_samples: 105114

# %% [markdown]
# ### 데이터 정규화
# 각 시계열을 독립적으로 정규화하여 비슷한 범위를 가진 작은 값으로 바꾸기 위해 데이터 정규화 진행

# %%
mean = raw_data[:num_train_samples].mean(axis=0)
raw_data -= mean
std = raw_data[:num_train_samples].std(axis=0)
raw_data /= std

# %% [markdown]
# 해당 데이터셋에는 중복 샘플이 많다(샘플 N과 샘플 N+1은 대부분 타임스텝이 중복됨)
# 따라서, 모든 샘플을 메모리에 적재하면 낭비가 심하므로, raw_data와 temperature 배열만 메모리에 유지하고 그때그때 샘플을 생성해야 한다.
#
# 케라스에 내장된 데이터셋 유틸리티 사용 -> timeseries_dataset_from_array()
#
# 훈련, 검증, 테스트를 위해 3개의 데이터셋 생성
# - sampling_rate = 6: 시간당 하나의 데이터 포인트가 샘플링된다. 즉, 6개의 데이터 포인트 중 하나만 사용
# - sequence_length = 120: 이전 5일간(120시간) 데이터 사용
# - delay = sampling_rate * (sequence_length + 24 - 1): 시퀀스 타깃은 시퀀스 끝에서 24시간 후의 온도

# %%
import tensorflow as tf

sampling_rate = 6
sequence_length = 120
delay = sampling_rate * (sequence_length + 24 - 1)
batch_size = 256

train_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=0,
    end_index=num_train_samples)

val_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples,
    end_index=num_train_samples + num_val_samples)

test_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples + num_val_samples)
# Out:
# Metal device set to: Apple M1
# 2023-01-27 16:53:44.317708: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-27 16:53:44.317806: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
for samples, targets in train_dataset:
    print("샘플 크기:", samples.shape)
    print("타깃 크기:", targets.shape)
    break
# Out:
# 2023-01-27 16:53:44.444595: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 샘플 크기: (256, 120, 14)
# 타깃 크기: (256,)

# %% [markdown]
# ### 상식 수준의 기준점
#
# 상식적인 기준 모델의 평균 절댓값 오차(MAE) 계산하기
# -> np.mean(np.abs(preds - targets)) 활용

# %%
def evaluate_naive_method(dataset):
    total_abs_err = 0.
    samples_seen = 0
    for samples, targets in dataset:
        preds = samples[:, -1, 1] * std[1] + mean[1]
        total_abs_err += np.sum(np.abs(preds - targets))
        samples_seen += samples.shape[0]
    return total_abs_err / samples_seen

print(f"검증 MAE: {evaluate_naive_method(val_dataset):.2f}")
print(f"테스트 MAE: {evaluate_naive_method(test_dataset):.2f}")
# Out:
# 검증 MAE: 2.44
# 테스트 MAE: 2.62

# %% [markdown]
# ### 기본적인 머신 러닝 모델 시도해보기
#
# 2개의 Dense 층 통과시키는 완전 연결 네트워크 <br>
# 전형적인 회귀 문제이므로, 마지막 Dense 층에 활성화 함수 적용 x

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(sequence_length, raw_data.shape[-1]))
x = layers.Flatten()(inputs)
x = layers.Dense(16, activation="relu")(x)
outputs = layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

callbacks = [
    keras.callbacks.ModelCheckpoint("jena_dense.keras",
                                    save_best_only=True)
]
model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
history = model.fit(train_dataset,
                    epochs=10,
                    validation_data=val_dataset,
                    callbacks=callbacks)

model = keras.models.load_model("jena_dense.keras")
print(f"테스트 MAE: {model.evaluate(test_dataset)[1]:.2f}")
# Out:
# Epoch 1/10
#   1/819 [..............................] - ETA: 4:03 - loss: 152.6318 - mae: 10.3472
# 2023-01-27 16:53:49.695246: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 815/819 [============================>.] - ETA: 0s - loss: 12.9163 - mae: 2.7794
# 2023-01-27 16:53:56.857662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 819/819 [==============================] - 10s 12ms/step - loss: 12.8994 - mae: 2.7775 - val_loss: 15.1885 - val_mae: 3.0784
# Epoch 2/10
# 819/819 [==============================] - 9s 11ms/step - loss: 9.0888 - mae: 2.3708 - val_loss: 9.9052 - val_mae: 2.4940
# Epoch 3/10
# 819/819 [==============================] - 9s 11ms/step - loss: 8.3628 - mae: 2.2769 - val_loss: 10.2302 - val_mae: 2.5353
# Epoch 4/10
# 819/819 [==============================] - 9s 11ms/step - loss: 7.9306 - mae: 2.2177 - val_loss: 10.5161 - val_mae: 2.5722
# Epoch 5/10
# 819/819 [==============================] - 10s 12ms/step - loss: 7.5777 - mae: 2.1684 - val_loss: 11.0227 - val_mae: 2.6229
# Epoch 6/10
# 819/819 [==============================] - 70s 86ms/step - loss: 29.0856 - mae: 4.2415 - val_loss: 17.6480 - val_mae: 3.2742
# Epoch 47/50
# 819/819 [==============================] - 70s 86ms/step - loss: 28.9665 - mae: 4.2282 - val_loss: 17.6005 - val_mae: 3.2703
# Epoch 48/50
# 819/819 [==============================] - 71s 86ms/step - loss: 29.0326 - mae: 4.2385 - val_loss: 17.6263 - val_mae: 3.2711
# Epoch 49/50
# 819/819 [==============================] - 70s 86ms/step - loss: 28.9730 - mae: 4.2341 - val_loss: 17.5888 - val_mae: 3.2671
# Epoch 50/50
# 819/819 [==============================] - 70s 85ms/step - loss: 28.9719 - mae: 4.2312 - val_loss: 17.6510 - val_mae: 3.2719
# 2023-01-27 18:34:49.874151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-27 18:34:49.987477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-27 18:34:50.207954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 405/405 [==============================] - 15s 35ms/step - loss: 11.8368 - mae: 2.6845
# 테스트 MAE: 2.68

# %%
loss = history.history["mae"]
val_loss = history.history["val_mae"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, "bo", label="Training MAE")
plt.plot(epochs, val_loss, "b", label="Validation MAE")
plt.title("Training and validation MAE")
plt.legend()
plt.show()

# %% [markdown]
# #### 양방향 RNN 사용하기

# %%
def train_generator():
    while True:
        for samples, targets in train_dataset:
            yield samples[:, ::-1, :], targets

def val_generator():
    while True:
        for samples, targets in val_dataset:
            yield samples[:, ::-1, :], targets
        
train_gen = train_generator()
val_gen = val_generator()

# %%
inputs = keras.Input(shape=(sequence_length, raw_data.shape[-1]))
# 훈련 속도를 놓이기 위해 순환 드롭아웃을 제외합니다.
# x = layers.LSTM(32, recurrent_dropout=0.25)(inputs)
x = layers.LSTM(32)(inputs)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
history = model.fit(train_gen,
                    epochs=10,
                    steps_per_epoch=819,
                    validation_data=val_gen,
                    validation_steps=410)
# Out:
# Epoch 1/10
# 2023-01-27 19:12:56.465183: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-27 19:12:56.583711: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-27 19:12:56.819307: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 819/819 [==============================] - ETA: 0s - loss: 36.6419 - mae: 4.6210
# 2023-01-27 19:13:26.089594: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-27 19:13:26.126780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 819/819 [==============================] - 39s 46ms/step - loss: 36.6419 - mae: 4.6210 - val_loss: 17.4441 - val_mae: 3.2797
# Epoch 2/10
# 819/819 [==============================] - 36s 44ms/step - loss: 21.6695 - mae: 3.6292 - val_loss: 16.4554 - val_mae: 3.1613
# Epoch 3/10
# 819/819 [==============================] - 37s 45ms/step - loss: 19.6543 - mae: 3.4488 - val_loss: 15.6463 - val_mae: 3.1268
# Epoch 4/10
# 819/819 [==============================] - 37s 45ms/step - loss: 17.9881 - mae: 3.3019 - val_loss: 14.4325 - val_mae: 2.9652
# Epoch 5/10
# 819/819 [==============================] - 38s 47ms/step - loss: 17.0484 - mae: 3.1947 - val_loss: 14.7140 - val_mae: 2.9673
# Epoch 6/10
# 819/819 [==============================] - 38s 47ms/step - loss: 15.9449 - mae: 3.0846 - val_loss: 14.6369 - val_mae: 2.9656
# Epoch 7/10
# 819/819 [==============================] - 38s 46ms/step - loss: 15.2513 - mae: 3.0019 - val_loss: 13.9130 - val_mae: 2.9058
# Epoch 8/10
# 819/819 [==============================] - 38s 46ms/step - loss: 13.6607 - mae: 2.8549 - val_loss: 12.7108 - val_mae: 2.8020
# Epoch 9/10
# 819/819 [==============================] - 37s 45ms/step - loss: 12.5167 - mae: 2.7440 - val_loss: 10.7905 - val_mae: 2.5709
# Epoch 10/10
# 819/819 [==============================] - 38s 46ms/step - loss: 12.0105 - mae: 2.6881 - val_loss: 10.9161 - val_mae: 2.5795
